# %%
import os 
try:
    os.chdir("../../plot")
except:
    print(os.getcwd())

# %%
import json 
from scalar.lineplot import *

# %%
with open("config.json")  as jsonfile:
    cfg = json.load(jsonfile)

# %%
cfg['data'] =  pd.read_csv("data/annealing.csv")
cfg['x'] =  cfg['data'].index
cfg['y'] = "beta"

lineplot(cfg)
