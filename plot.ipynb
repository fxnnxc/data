# %%
import json 
from scalar.lineplot import *

# %%
with open("config.json")  as jsonfile:
    cfg = json.load(jsonfile)

# %%
cfg['line']['data'] =  pd.read_csv("data/annealing.csv")
cfg['line']['x'] =  cfg['line']['data'].index
cfg['line']['y'] = "beta"


lineplot(cfg)
